# %%
import pandas as pd

# %% [markdown]
# ### Loading NHANES data
#
# This data was in ```.dat``` format along with ```.sas``` program file downloaded from [here]().
# ![image.png](attachment:image.png)
# We use [SAS OnDemand for acadamics](https://www.sas.com/en_in/software/on-demand-for-academics.html) online platform to convert the data into ```.csv``` format.

# %%
data = pd.read_csv('../../data/NHANES-III/youth.csv.gz')
data.head(2)
# Out:
#    SEQN  DMPFSEQ  DMPSTAT  DMARETHN  DMARACER  DMAETHNR  HSSEX  HSDOIMO  \
# 0     7      855        2         2         2         3      2        2
# 1    12     4160        2         1         1         3      2        2
#
#    HSAGEIR  HSAGEU  ...  HYK11AN  HYK12SN  HYK9DO  HYK9EO  HYK9FO  HYK11AO  \
# 0        3       2  ...      NaN      NaN     NaN     NaN     NaN      NaN
# 1        2       1  ...      NaN      NaN     NaN     NaN     NaN      NaN
#
#    HYK12SO  HYM1  HYM2  HYM3
# 0      NaN     1     1     1
# 1      NaN     1     1     1
#
# [2 rows x 687 columns]

# %% [markdown]
# ### Checking number of counties available

# %%
print('Number of unique counties in dataset:', data['DMPCNTYR'].dropna().unique().shape)
# Out:
# Number of unique counties in dataset: (31,)
